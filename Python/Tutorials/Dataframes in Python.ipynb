# %%
import pandas as pd
import numpy as np
import string, random

# %%
df = pd.DataFrame({
    'a' : np.random.randint(1,100,15),
    'b' : np.random.randint(1000,2000,15),
    'c' : [random.choice(string.ascii_lowercase) for i in range(0,15)]
})

df
# Out:
#      a     b  c
# 0   77  1318  m
# 1   70  1667  k
# 2   37  1007  i
# 3   33  1847  g
# 4   91  1087  e
# 5   26  1214  j
# 6   14  1349  g
# 7   33  1177  b
# 8   13  1737  o
# 9   17  1475  l
# 10  15  1927  g
# 11   5  1513  x
# 12  21  1834  k
# 13  37  1392  a
# 14  52  1010  k

# %%
df.head(3)
# Out:
#     a     b  c
# 0  77  1318  m
# 1  70  1667  k
# 2  37  1007  i

# %%
df.tail()
# Out:
#      a     b  c
# 10  15  1927  g
# 11   5  1513  x
# 12  21  1834  k
# 13  37  1392  a
# 14  52  1010  k

# %%
df.dtypes
# Out:
# a     int32
# b     int32
# c    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       15 non-null     int32
#  1   b       15 non-null     int32
#  2   c       15 non-null     object
# dtypes: int32(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.shape
# Out:
# (15, 3)

# %%
ls = [50,1050,'z']
ls
# Out:
# [50, 1050, 'z']

# %%
ls = pd.Series(ls, index = ['a', 'b', 'c'])
ls
# Out:
# a      50
# b    1050
# c       z
# dtype: object

# %%
df = df.append(ls, ignore_index = True)

# %%
df.shape
# Out:
# (16, 3)

# %%
df['d'] = np.random.randint(10000,20000,16)
df
# Out:
#      a     b  c      d
# 0   77  1318  m  15141
# 1   70  1667  k  13518
# 2   37  1007  i  11431
# 3   33  1847  g  12567
# 4   91  1087  e  16084
# 5   26  1214  j  10444
# 6   14  1349  g  18818
# 7   33  1177  b  11099
# 8   13  1737  o  15859
# 9   17  1475  l  14582
# 10  15  1927  g  10800
# 11   5  1513  x  12594
# 12  21  1834  k  12318
# 13  37  1392  a  14748
# 14  52  1010  k  16540
# 15  50  1050  z  10664

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.loc[[0,2,3,4],['a', 'c']]
# Out:
#     a  c
# 0  77  m
# 2  37  i
# 3  33  g
# 4  91  e

# %%
df.columns = ["CapA", 'CapB', "CapC", "CapD"]
df.head()
# Out:
#    CapA  CapB CapC   CapD
# 0    77  1318    m  15141
# 1    70  1667    k  13518
# 2    37  1007    i  11431
# 3    33  1847    g  12567
# 4    91  1087    e  16084

# %%
df.rename(columns = {'CapA' : 'A', 'CapC' : 'C'}, inplace = True)

# %%
df
# Out:
#      A  CapB  C   CapD
# 0   77  1318  m  15141
# 1   70  1667  k  13518
# 2   37  1007  i  11431
# 3   33  1847  g  12567
# 4   91  1087  e  16084
# 5   26  1214  j  10444
# 6   14  1349  g  18818
# 7   33  1177  b  11099
# 8   13  1737  o  15859
# 9   17  1475  l  14582
# 10  15  1927  g  10800
# 11   5  1513  x  12594
# 12  21  1834  k  12318
# 13  37  1392  a  14748
# 14  52  1010  k  16540
# 15  50  1050  z  10664

# %%
df['A'] > 70
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: A, dtype: bool

# %%
df.loc[(df['A'] > 70) & (df['C'] == 'm') , : ]
# Out:
#     A  CapB  C   CapD
# 0  77  1318  m  15141

# %%
df.to_csv('dataFrame.csv', index = False)

# %%
temp = pd.read_csv('dataFrame.csv')
temp.head()
# Out:
#     A  CapB  C   CapD
# 0  77  1318  m  15141
# 1  70  1667  k  13518
# 2  37  1007  i  11431
# 3  33  1847  g  12567
# 4  91  1087  e  16084

# %%
from pydataset import data
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
pd.set_option('display.max_rows', 800)
data()
# Out:
#                     dataset_id  \
# 0                AirPassengers
# 1                      BJsales
# 2                          BOD
# 3                 Formaldehyde
# 4                 HairEyeColor
# 5                 InsectSprays
# 6               JohnsonJohnson
# 7                    LakeHuron
# 8             LifeCycleSavings
# 9                         Nile
# 10               OrchardSprays
# 11                 PlantGrowth
# 12                   Puromycin
# 13                     Titanic
# 14                 ToothGrowth
# 15               UCBAdmissions
# 16              UKDriverDeaths
# 17                       UKgas
# 18                 USAccDeaths
# 19                   USArrests
# 20              USJudgeRatings
# 21       USPersonalExpenditure
# 22                    VADeaths
# 23                    WWWusage
# 24                 WorldPhones
# 25                    airmiles
# 26                  airquality
# 27                    anscombe
# 28                      attenu
# ...

# %%
df2 = data('planets')
df2.head()
# Out:
#     mass  period  eccen
# 1  0.120   4.950   0.00
# 2  0.197   3.971   0.00
# 3  0.210  44.280   0.34
# 4  0.220  75.800   0.28
# 5  0.230   6.403   0.08
